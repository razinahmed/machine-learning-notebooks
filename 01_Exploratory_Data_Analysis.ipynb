# %% [markdown]
# # Exploratory Data Analysis (EDA) Blueprint
#
# This notebook demonstrates a robust, standardized pipeline for conducting Exploratory Data Analysis on a tabular dataset using Pandas and Seaborn.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set_theme(style="whitegrid")
print("Libraries loaded successfully.")
